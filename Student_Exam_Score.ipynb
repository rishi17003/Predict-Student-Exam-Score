# %%
import pandas as pd
import numpy as np

def generate_random_dataset(num_rows):
    data = {
        "Study Hours": np.random.randint(4, 13, num_rows),
        "Attendance (%)": np.random.randint(50, 101, num_rows),
        "Assignments Completed": np.random.randint(2, 8, num_rows),
    }
    return pd.DataFrame(data)

random_dataset = generate_random_dataset(500)
print(random_dataset)
# Out:
#      Study Hours  Attendance (%)  Assignments Completed
# 0              8              77                      3
# 1              7              93                      5
# 2              6              70                      3
# 3              6              84                      6
# 4             12              50                      4
# ..           ...             ...                    ...
# 495            8              71                      7
# 496           12              97                      5
# 497           11              64                      3
# 498            4              62                      3
# 499            8              60                      7
#
# [500 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
import pandas as pd
from sklearn.linear_model import LinearRegression

x=df[["Study Hours","Attendance (%)","Assignments Completed"]]
y=df[["Final Exam Score"]]

X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.4,random_state=42)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2_score = model.score(X_test, y_test)
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2_score}")
# Out:
# Mean Squared Error: 0.0011337868480734003
# R² Score: 0.9998185941043083

# %%
import pandas as pd

correlation_matrix = df.corr()
print("Correlation Matrix:")
print(correlation_matrix)

correlation_with_target = df.corr()["Final Exam Score"].drop("Final Exam Score")
print("\nCorrelation with Final Exam Score:")
print(correlation_with_target)
# Out:
# Correlation Matrix:
#                        Study Hours  Attendance (%)  Assignments Completed  \
# Study Hours               1.000000        1.000000               0.980581
# Attendance (%)            1.000000        1.000000               0.980581
# Assignments Completed     0.980581        0.980581               1.000000
# Final Exam Score          1.000000        1.000000               0.980581
#
#                        Final Exam Score
# Study Hours                    1.000000
# Attendance (%)                 1.000000
# Assignments Completed          0.980581
# Final Exam Score               1.000000
#
# Correlation with Final Exam Score:
# Study Hours              1.000000
# Attendance (%)           1.000000
# Assignments Completed    0.980581
# Name: Final Exam Score, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

x=["Study Hours","Attendance (%)","Assignments Completed"]
y=["Final Exam Score"]

sns.pairplot(df,x_vars=x,y_vars=y,kind="reg")
plt.show()

# %%
for feature in ["Study Hours", "Attendance (%)", "Assignments Completed"]:
    plt.figure(figsize=(6,4))
    plt.scatter(df[feature],df["Final Exam Score"],alpha=0.7,edgecolor='k')
    plt.title(f"{feature} vs Final Exam Score")
    plt.xlabel(feature)
    plt.ylabel("Final Exam Score")
    plt.grid(True)
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd

x = df[["Study Hours", "Attendance (%)", "Assignments Completed"]]
y = df[["Final Exam Score"]]

scaler = StandardScaler()
x_normalized = scaler.fit_transform(x)


X_train, X_test, y_train, y_test = train_test_split(x_normalized, y, test_size=0.4, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
r2_score = model.score(X_test, y_test)

print(f"Mean Squared Error: {mse}")
print(f"R2 score: {r2_score}")
# Out:
# Mean Squared Error: 1.3176758306628527
# R2 score: 0.7891718670939436

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

x = df[["Study Hours", "Attendance (%)", "Assignments Completed"]]
y = df["Final Exam Score"]

scaler = StandardScaler()
x_normalized = scaler.fit_transform(x)

df_normalized = pd.DataFrame(x_normalized, columns=x.columns)
df_normalized["Final Exam Score"] = y

correlation_matrix = df_normalized.corr()


plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

sns.pairplot(df, x_vars=["Study Hours", "Attendance (%)", "Assignments Completed"], y_vars=["Final Exam Score"], kind="reg")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

x = df[["Study Hours", "Attendance (%)", "Assignments Completed"]]
y = df["Final Exam Score"]

for i, feature in enumerate(x.columns):
    plt.figure(figsize=(6, 4))
    plt.scatter(x_normalized[:, i], y, alpha=0.7, edgecolor='k')
    plt.title(f"{feature} vs Final Exam Score")
    plt.xlabel(feature)
    plt.ylabel("Final Exam Score")
    plt.grid(True)
    plt.show()
